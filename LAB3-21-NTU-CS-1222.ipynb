# %%
#Implement Loan Class with following specs and use this class: 
class Loan:
    annualInterestRate = 2.5 
    numberOfYears = 1 
    loanAmount = 1000 
    borrower = 0
    def getAnnualInterestRate(self):
        return self.annualInterestRate
    def getNumberOfYears(self):
        return self.numberOfYears
    def getLoanAmount(self):
        return self.loanAmount
    def getBorrowAmount(self):
        return self.borrower
    def SetAnnualInterestRate(self,InterestRate):
        self.annualInterestRate = InterestRate
    def SetNumberOfYears(self,Years):
        self.numberOfYears = Years
    def SetLoanAmount(self,loan):
        self.loanAmount = loan
    def SetBorrowAmount(self,borrowAmount):
        self.borrower = borrowAmount
    def getMonthlyPayment(self): 
        monthlyInterestRate = self.annualInterestRate / 1200  
        monthlyPayment = self.loanAmount * monthlyInterestRate / (1 - (1 + monthlyInterestRate) ** (-self.numberOfYears * 12))  
        return monthlyPayment

    def getTotalPayment(self): 
        totalPayment = self.getMonthlyPayment() * self.numberOfYears * 12 
        return totalPayment 
    def display(self):
        print(f"Annual Interest Rate is {self.annualInterestRate} And Number ofYears is {self.numberOfYears} And Loan Amount is {self.loanAmount} And borrowed Amount is {self.borrower}")
        print("And Monthly Payment is",self.getMonthlyPayment())
        print("And Total Payment is",self.getTotalPayment())       
obj = Loan()
obj.display()
# Out:
# Annual Interest Rate is 2.5 And Number ofYears is 1 And Loan Amount is 1000 And borrowed Amount is 0
# And Monthly Payment is 84.46611116394396
# And Total Payment is 1013.5933339673276

# %%
#mplement BMI Class with following : Private Data Initializer: 
class BMI:
    def __init__(self,name,age,weight,height):
        self.name = name
        self.age = age
        self.weight = weight
        self.height = height
    def getBMI(self):
          return self.weight / (self.height ** 2)
    def getStatus(self):
        bmi = self.getBMI()
        if bmi <=18.5:
            print("You are underweight")
        else:
            print("You are overweight")
    def getName(self):
        return self.name
    def getAge(self):
        return self.age
    def getWeight(self):
        return self.weight
    def getHeight(self):
        return self.height
    
obj1 = BMI("Fatima",21,53,1.64)
obj1.getStatus()
# Out:
# You are overweight

# %%
#Create a Python class Person with attributes
class Person:
    name = ""
    age = 0
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def display(self):
        print(f"Name is {self.name} and Age is {self.age}")
        
class Student(Person):
    Section = ""
    def __init__(self,name,age,Section):
        super().__init__(name,age)
        self.Section = Section
    def Stddisplay(self):
        super().display()
        print(f"Student Section is {self.Section}")

Std1 = Student("Fatima",21,"A")
Std1.Stddisplay()
# Out:
# Name is Fatima and Age is 21
# Student Section is A

# %%
#Write four classes called Person, Student, Employee and StudentEmployee. The details of 
#each class are as follows: 
class Person:
    def __init__(self,name,YearofBirth,SocialNum):
        self.name = name
        self.YearOfBirth = YearofBirth
        self.SocialNum = SocialNum
    def display(self):
        print(f"Name is {self.name} and Year of Birth is {self.YearOfBirth} and Social Num is {self.SocialNum}")
        
class Student(Person):
    def __init__(self,name,YearofBirth,SocialNum,discipline,RegNo):
        super().__init__(name,YearofBirth,SocialNum)
        self.disipline = discipline
        self.RegNo = RegNo
    def Stddisplay(self):
        super().display()
        print(f"Student Discipline is {self.disipline} and Year of Birth is {self.YearOfBirth}")
class Employee(Person):
    def __init__(self,name,YearofBirth,SocialNum,Salary):
        super().__init__(name,YearofBirth,SocialNum)
        self.Salary = Salary
    def Emplyoedisplay(self):
        super().display()
        print(f"{self.name} salary is {self.Salary}")
class StdEmplyoee(Student):
    def __init__(self, name, YearofBirth, SocialNum, discipline, RegNo,stdSalary):
        super().__init__(name, YearofBirth, SocialNum, discipline, RegNo)
        self.StdSalary = stdSalary
    def StdEmplyoeDisplay(self):
        super().Stddisplay()
        print(f"{self.name}  Salary is {self.StdSalary}")
    
Emp = Employee("Fatima",2002,1222,50000)
StdEmp = StdEmplyoee("Zainab",2002,1117,"BSCS",1117,700000)
Emp.Emplyoedisplay()
StdEmp.StdEmplyoeDisplay()
# Out:
# Name is Fatima and Year of Birth is 2002 and Social Num is 1222
# Fatima salary is 50000
# Name is Zainab and Year of Birth is 2002 and Social Num is 1117
# Student Discipline is BSCS and Year of Birth is 2002
# Zainab  Salary is 700000

# %%
# Imagine a publishing company that markets both Book and CD versions of its works. 
class Publication:
    def __init__(self):
        self.title = ""
        self.author = ""
        self.price = 0.0

    def get_data(self):
        self.title = input("Enter title: ")
        self.author = input("Enter author: ")
        self.price = float(input("Enter price: "))

    def display_data(self):
        print("Title:", self.title)
        print("Author:", self.author)
        print("Price:", self.price)


class Book(Publication):
    def __init__(self):
        super().__init__()
        self.num_pages = 0

    def get_data(self):
        super().get_data()
        self.num_pages = int(input("Enter number of pages: "))

    def display_data(self):
        super().display_data()
        print("Number of pages:", self.num_pages)


class CD(Publication):
    def __init__(self):
        super().__init__()
        self.pl_time = 0

    def get_data(self):
        super().get_data()
        self.pl_time = int(input("Enter playing time in hours: "))

    def display_data(self):
        super().display_data()
        print("Playing time :", self.pl_time)


# Test the classes
book = Book()
print("Enter details for the book:")
book.get_data()
print("\n")

cd = CD()
print("Enter details for the CD:")
cd.get_data()
print("\nCD Details:")
cd.display_data()
print("\nBook Details:")
book.display_data()
# Out:
# Enter details for the book:
#
#
# Enter details for the CD:
#
# CD Details:
# Title: Beauty and beast
# Author: ABC
# Price: 300.0
# Playing time : 2
#
# Book Details:
# Title: harry potter
# Author: Jk rowling
# Price: 3000.0
# Number of pages: 500

# %%
#Overload these four arithmetic operators: + - * / for complex class
class Operator:
    def __init__(self,num1):
        self.num1 = num1
    def __add__(self,other):
        return self.num1+other.num1
    def __sub__(self,other):
        return self.num1-other.num1
    def __mul__(self,other):
        return self.num1*other.num1
    def __truediv__(self,other):
        return self.num1/other.num1
obj1 = Operator(10)
obj2 = Operator(30)

print(obj1+obj2)
print(obj1-obj2)
print(obj1*obj2)
print(obj1/obj2)
# Out:
# 40
# -20
# 300
# 0.3333333333333333

# %%
#Create a class RationalNumber with the following capabilities: 
import math

class RationalNumber:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero")
        self.numerator = numerator 
        self.denominator = denominator 

    def __add__(self, other):
        new_numerator = self.numerator * other.denominator + other.numerator * self.denominator
        new_denominator = self.denominator * other.denominator
        return RationalNumber(new_numerator, new_denominator)

    def __sub__(self, other):
        new_numerator = self.numerator * other.denominator - other.numerator * self.denominator
        new_denominator = self.denominator * other.denominator
        return RationalNumber(new_numerator, new_denominator)

    def __mul__(self, other):
        new_numerator = self.numerator * other.numerator
        new_denominator = self.denominator * other.denominator
        return RationalNumber(new_numerator, new_denominator)

    def __truediv__(self, other):
        if other.numerator == 0:
            raise ValueError("Division by zero")
        new_numerator = self.numerator * other.denominator
        new_denominator = self.denominator * other.numerator
        return RationalNumber(new_numerator, new_denominator)

    def __eq__(self, other):
        return self.numerator == other.numerator and self.denominator == other.denominator

    def __lt__(self, other):
        return self.numerator * other.denominator < other.numerator * self.denominator

    def __gt__(self, other):
        return self.numerator * other.denominator > other.numerator * self.denominator

    def __le__(self, other):
        return self.numerator * other.denominator <= other.numerator * self.denominator

    def __ge__(self, other):
        return self.numerator * other.denominator >= other.numerator * self.denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example usage:
n1 = RationalNumber(1, 2)
n2 = RationalNumber(1, 2)
print("n1:", n1)
print("n2:", n2)
print("n1 + n2:", n1 +  n2)
print("n1 - n2:", n1 -  n2)
print("n1 * n2:", n1 *  n2)
print("n1 / n2:", n1 /  n2)
print("n1 == n2:", n1 ==  n2)
print("n1 < n2:", n1 <  n2)
print("n1 > n2:", n1 > n2)
# Out:
# n1: 1/2
# n2: 1/2
# n1 + n2: 4/4
# n1 - n2: 0/4
# n1 * n2: 1/4
# n1 / n2: 2/2
# n1 == n2: True
# n1 < n2: False
# n1 > n2: False

# %%
#Task Implement Question 1 using appropriate GUI. 
from tkinter import Tk, Entry, Label, Button,messagebox
window  = Tk() 
SKY = "#87CEFA"

def calculate_interest_rate():
    try:
        interest_rate = float(annual_interest_rate.get())
        years = int(year_input.get())
        loan = int(loan_input.get())
        borrowes = borrower_input.get()
        
        monthlyInterestRate = interest_rate / 1200
        monthlyPayment = loan * monthlyInterestRate / (1 - (1 + monthlyInterestRate) ** (years * 12))
        print(monthlyPayment)
    except:
        messagebox.showerror("Error", "Please enter a valid number")

window.geometry("512x512")
window.configure(padx=20,pady=20,bg=SKY)

interest_label = Label(text="Enter Interrest rate",bg=SKY)
interest_label.grid(column=0,row=0)
annual_interest_rate = Entry(width=30,bg=SKY)
annual_interest_rate.grid(column=3,row=0,padx=20,pady=10)

year_label = Label(text="Enter No of years",bg=SKY)
year_label.grid(column=0,row=1)
year_input = Entry(width=30,bg=SKY)
year_input.grid(column=3,row=1,padx=20,pady=10)


loan_label = Label(text="Enter Loan amount",bg=SKY)
loan_label.grid(column=0,row=2)
loan_input = Entry(width=30,bg=SKY)
loan_input.grid(column=3,row=2,padx=20,pady=10)

borrower_label = Label(text="Enter borrower name", bg=SKY)
borrower_label.grid(column=0,row=3)
borrower_input = Entry(width=30,bg=SKY)
borrower_input.grid(column=3,row=3,padx=20,pady=10)

button = Button(text="Calculate",command=calculate_interest_rate)
button.grid(column=3,row=4)


window.mainloop()

# %%
#Task Implement Question 2 using appropriate GUI. 
from tkinter import Tk,Entry,Label,messagebox,Button
window = Tk()
PURPLE="#9370DB"
def BMI():
    try:
        Wg = int(Wg_input.get())
        Ht = float(Ht_input.get())
        print(Wg/(Ht*Ht))
    except:
        messagebox.showerror("Error", "Please enter a valid number")

window.geometry = ("512x512")
window.title = "BMI Calculations"
window.configure(padx=20,pady=20,bg=PURPLE)
Wg_label = Label(text="Enter weight in kg ")
Wg_label.grid(column=0,row=0)
Wg_input = Entry(width=30, bg=PURPLE)
Wg_input.grid(column=3,row=0)
Ht_label = Label(text="Enter height in meters ")
Ht_label.grid(column=0,row=1)
Ht_input = Entry(width=30,bg=PURPLE)
Ht_input.grid(column=3,row=1)

button = Button(text="Calculate",command=BMI)
button.grid(column=3,row=2)

window.mainloop()
